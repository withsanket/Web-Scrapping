# %%
import pandas as pd
from bs4 import BeautifulSoup
import html5lib
import requests
import csv
ProductName = []
Prices = []
Description = []
Reviews= []
for i in range(2,5):
    url = 'https://www.flipkart.com/search?q=mobile+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='+str(i)
    r = requests.get(url)
    print(r)

    soup = BeautifulSoup(r.text, 'lxml')

    box = soup.find("div", class_ = "_1YokD2 _3Mn1Gg")
    names = box.find_all("div" ,class_= "_4rR01T")
    # print(names)

    for i in names:
        name = i.text
        ProductName.append(name)
    # print(ProductName)
    # print(len(ProductName))

    prices = box.find_all("div", class_ = "_30jeq3 _1_WHN1")
    # print(prices)

    for i in prices:
        name = i.text
        Prices.append(name)
    # print(Prices)
    # print(len(Prices))



    des = box.find_all("ul", class_ = "_1xgFaf")
    for i in des:
        name = i.text
        Description.append(name)
    # print(Description)
    # print(len(Description))


    review = box.find_all("div", class_="_3LWZlK")
    for i in review:
        name = i.text
        Reviews.append(name)
    print(Reviews)
    print(len(Reviews))

    df = pd.DataFrame({"Product Name":ProductName, "Prices":Prices, "Description":Description, "Reviews":Reviews})
    print(df)
    
df.to_csv("E:/Project/Web-Scapping/Phones_Under_50000 .csv")
# Out:
# <Response [200]>
# ['4.5', '4.3', '4.1', '4.1', '3.8', '3.8', '4.1', '4.1', '4.4', '4.1', '4', '4.4', '4.1', '4.2', '4.2', '4.3', '4.6', '4.2', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6']
# 24
#                                          Product Name   Prices  \
# 0                  vivo X70 Pro (Aurora Dawn, 256 GB)  ₹45,999
# 1                 OnePlus 10T 5G (Jade Green, 128 GB)  ₹45,999
# 2                    REDMI Note 12 (Ice Blue, 128 GB)  ₹13,999
# 3                 REDMI Note 12 (Sunrise Gold, 64 GB)  ₹11,999
# 4            OnePlus 9 Pro 5G (Stellar Black, 256 GB)  ₹49,999
# 5               OnePlus 9 Pro 5G (Pine Green, 256 GB)  ₹48,880
# 6                 REDMI Note 12 (Lunar Black, 128 GB)  ₹13,999
# 7                REDMI Note 12 (Sunrise Gold, 128 GB)  ₹13,999
# 8            OPPO Reno8 Pro 5G (Glazed Black, 256 GB)  ₹41,704
# 9   Xiaomi 11T Pro 5G Hyperphone (Celestial Magic,...  ₹49,990
# 10           OnePlus 10T 5G (Moonstone Black, 256 GB)  ₹51,054
# 11                realme X50 Pro (Moss Green, 256 GB)  ₹32,575
# 12                 REDMI Note 12 (Lunar Black, 64 GB)  ₹11,999
# 13                    POCO C55 (Forest Green, 128 GB)   ₹7,799
# 14       SAMSUNG Galaxy A73 5G (Awesome Gray, 256 GB)  ₹45,000
# 15        OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)  ₹39,999
# 16                  APPLE iPhone 8 Plus (Gold, 64 GB)  ₹49,900
# 17                  Mi 10T Pro (Cosmic Black, 128 GB)  ₹47,999
# 18            APPLE iPhone 8 Plus (Space Grey, 64 GB)  ₹49,900
# 19                APPLE iPhone 8 Plus (Silver, 64 GB)  ₹49,900
# 20                     APPLE iPhone 12 (Blue, 128 GB)  ₹44,999
# 21                    APPLE iPhone 12 (Black, 128 GB)  ₹44,999
# 22                    APPLE iPhone 12 (White, 128 GB)  ₹44,999
# 23                      APPLE iPhone 12 (Blue, 64 GB)  ₹40,999
#
#                                           Description Reviews
# 0   8 GB RAM | 256 GB ROM16.66 cm (6.56 inch) Full...     4.5
# 1   8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Displ...     4.3
# 2   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.1
# 3   6 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....     4.1
# 4   12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...     3.8
# 5   12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...     3.8
# 6   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.1
# 7   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.1
# 8   12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full...     4.4
# 9   12 GB RAM | 256 GB ROM16.94 cm (6.67 inch) Dis...     4.1
# 10  16 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...       4
# 11  12 GB RAM | 256 GB ROM16.36 cm (6.44 inch) Ful...     4.4
# 12  6 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....     4.1
# 13  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...     4.2
# 14  8 GB RAM | 256 GB ROM | Expandable Upto 1 TB17...     4.2
# 15  12 GB RAM | 256 GB ROM | Expandable Upto 7 GB1...     4.3
# 16  64 GB ROM13.97 cm (5.5 inch) Retina HD Display...     4.6
# 17  8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full...     4.2
# 18  64 GB ROM13.97 cm (5.5 inch) Retina HD Display...     4.6
# 19  64 GB ROM13.97 cm (5.5 inch) Retina HD Display...     4.6
# 20  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...     4.6
# 21  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...     4.6
# 22  128 GB ROM15.49 cm (6.1 inch) Super Retina XDR...     4.6
# 23  64 GB ROM15.49 cm (6.1 inch) Super Retina XDR ...     4.6
# <Response [200]>
# ['4.5', '4.3', '4.1', '4.1', '3.8', '3.8', '4.1', '4.1', '4.4', '4.1', '4', '4.4', '4.1', '4.2', '4.2', '4.3', '4.6', '4.2', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.1', '4.1', '4.3', '4.3', '4.3', '4.5', '4.1', '4.1', '4.5', '4.3', '4.1', '4.2', '4.6', '4.6', '4.4', '4.4', '4.3', '4.3', '4.4', '4.2', '4.5', '4.4']
# 48
#                                          Product Name   Prices  \
# 0                  vivo X70 Pro (Aurora Dawn, 256 GB)  ₹45,999
# 1                 OnePlus 10T 5G (Jade Green, 128 GB)  ₹45,999
# 2                    REDMI Note 12 (Ice Blue, 128 GB)  ₹13,999
# 3                 REDMI Note 12 (Sunrise Gold, 64 GB)  ₹11,999
# 4            OnePlus 9 Pro 5G (Stellar Black, 256 GB)  ₹49,999
# 5               OnePlus 9 Pro 5G (Pine Green, 256 GB)  ₹48,880
# 6                 REDMI Note 12 (Lunar Black, 128 GB)  ₹13,999
# 7                REDMI Note 12 (Sunrise Gold, 128 GB)  ₹13,999
# 8            OPPO Reno8 Pro 5G (Glazed Black, 256 GB)  ₹41,704
# 9   Xiaomi 11T Pro 5G Hyperphone (Celestial Magic,...  ₹49,990
# 10           OnePlus 10T 5G (Moonstone Black, 256 GB)  ₹51,054
# 11                realme X50 Pro (Moss Green, 256 GB)  ₹32,575
# 12                 REDMI Note 12 (Lunar Black, 64 GB)  ₹11,999
# 13                    POCO C55 (Forest Green, 128 GB)   ₹7,799
# 14       SAMSUNG Galaxy A73 5G (Awesome Gray, 256 GB)  ₹45,000
# 15        OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)  ₹39,999
# 16                  APPLE iPhone 8 Plus (Gold, 64 GB)  ₹49,900
# 17                  Mi 10T Pro (Cosmic Black, 128 GB)  ₹47,999
# 18            APPLE iPhone 8 Plus (Space Grey, 64 GB)  ₹49,900
# 19                APPLE iPhone 8 Plus (Silver, 64 GB)  ₹49,900
# 20                     APPLE iPhone 12 (Blue, 128 GB)  ₹44,999
# 21                    APPLE iPhone 12 (Black, 128 GB)  ₹44,999
# 22                    APPLE iPhone 12 (White, 128 GB)  ₹44,999
# 23                      APPLE iPhone 12 (Blue, 64 GB)  ₹40,999
# 24                   APPLE iPhone 12 (Purple, 128 GB)  ₹44,999
# 25                    APPLE iPhone 12 (Purple, 64 GB)  ₹40,999
# 26                 REDMI Note 12 (Lunar Black, 64 GB)  ₹11,999
# 27                   REDMI Note 12 (Ice Blue, 128 GB)  ₹13,999
# 28                      Google Pixel 7 (Snow, 128 GB)  ₹42,999
# 29                Google Pixel 7 (Lemongrass, 128 GB)  ₹42,999
# 30  Samsung Galaxy S21 FE 5G with Snapdragon 888 (...  ₹34,999
# 31               OnePlus 11R 5G (Sonic Black, 128 GB)  ₹39,989
# 32                REDMI Note 12 (Sunrise Gold, 64 GB)  ₹11,999
# 33                REDMI Note 12 (Lunar Black, 128 GB)  ₹13,999
# 34           OnePlus 11R 5G (Galactic Silver, 128 GB)  ₹39,799
# 35                  Google Pixel 7 (Obsidian, 128 GB)  ₹42,999
# 36               REDMI Note 12 (Sunrise Gold, 128 GB)  ₹13,999
# 37                    POCO C55 (Forest Green, 128 GB)   ₹7,799
# 38                       APPLE iPhone 12 (Red, 64 GB)  ₹40,999
# 39                      APPLE iPhone 12 (Red, 128 GB)  ₹44,999
# 40                  Nothing Phone (2) (White, 256 GB)  ₹44,999
# 41              Nothing Phone (2) (Dark Grey, 256 GB)  ₹44,999
# 42         OPPO Reno10 Pro 5G (Glossy Purple, 256 GB)  ₹39,999
# 43          OPPO Reno10 Pro 5G (Silvery Grey, 256 GB)  ₹39,999
# 44                   vivo V27 5G (Magic Blue, 256 GB)  ₹36,999
# 45           vivo V23 Pro 5G (Stardust Black, 256 GB)  ₹33,790
# 46               OnePlus 11R 5G (Sonic Black, 256 GB)  ₹44,974
# 47               vivo V27 Pro 5G (Magic Blue, 256 GB)  ₹39,999
#
#                                           Description Reviews
# 0   8 GB RAM | 256 GB ROM16.66 cm (6.56 inch) Full...     4.5
# 40  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full...     4.4
# 41  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full...     4.4
# 42  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full...     4.3
# 43  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full...     4.3
# 44  12 GB RAM | 256 GB ROM17.22 cm (6.78 Inch) Ful...     4.4
# 45  12 GB RAM | 256 GB ROM16.66 cm (6.56 inch) Ful...     4.2
# 46  16 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...     4.5
# 47  8 GB RAM | 256 GB ROM17.22 cm (6.78 inch) Full...     4.4
# <Response [200]>
# ['4.5', '4.3', '4.1', '4.1', '3.8', '3.8', '4.1', '4.1', '4.4', '4.1', '4', '4.4', '4.1', '4.2', '4.2', '4.3', '4.6', '4.2', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.6', '4.1', '4.1', '4.3', '4.3', '4.3', '4.5', '4.1', '4.1', '4.5', '4.3', '4.1', '4.2', '4.6', '4.6', '4.4', '4.4', '4.3', '4.3', '4.4', '4.2', '4.5', '4.4', '3.8', '4.5', '3.8', '4.4', '4.1', '4.1', '4.4', '4.2', '4.1', '4.1', '4.1', '4.2', '4.4', '4', '4.1', '4.2', '4.2', '4.1', '4', '4.5', '4.5', '4.2', '4.5', '4.5']
# 72
#                                 Product Name   Prices  \
# 0         vivo X70 Pro (Aurora Dawn, 256 GB)  ₹45,999
# 1        OnePlus 10T 5G (Jade Green, 128 GB)  ₹45,999
# 2           REDMI Note 12 (Ice Blue, 128 GB)  ₹13,999
# 3        REDMI Note 12 (Sunrise Gold, 64 GB)  ₹11,999
# 4   OnePlus 9 Pro 5G (Stellar Black, 256 GB)  ₹49,999
# ..                                       ...      ...
# 67        vivo X70 Pro (Aurora Dawn, 128 GB)  ₹44,990
# 68        APPLE iPhone 7 Plus (Gold, 128 GB)  ₹42,900
# 69     OPPO Reno10 5G (Silvery Grey, 256 GB)  ₹32,999
# 70                vivo V29 5G (Blue, 256 GB)  ₹36,999
# 71                 vivo V29 5G (Red, 256 GB)  ₹36,999
#
#                                           Description Reviews
# 0   8 GB RAM | 256 GB ROM16.66 cm (6.56 inch) Full...     4.5
# 1   8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Displ...     4.3
# 2   6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...     4.1
# 3   6 GB RAM | 64 GB ROM | Expandable Upto 1 TB16....     4.1
# 4   12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...     3.8
# ..                                                ...     ...
# 67  8 GB RAM | 128 GB ROM16.66 cm (6.56 inch) Full...     4.5
# 68  128 GB ROM13.94 cm (5.488 inch) Retina HD Disp...     4.5
# 69  8 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full ...     4.2
# 70  12 GB RAM | 256 GB ROM17.22 cm (6.78 inch) Ful...     4.5
# 71  12 GB RAM | 256 GB ROM17.22 cm (6.78 inch) Ful...     4.5
#
# [72 rows x 4 columns]
